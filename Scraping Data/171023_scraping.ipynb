# %% [markdown]
# # Scraping
# **Desti Ratna Komala - Data Scientist**
#
# *Wednesday, October 17th 2023*

# %% [markdown]
# **Scraping data is a process of importing information from a website or online documents into a spreadsheet**, by using python library such as, beautifulsoup, scrapy and selenium or scraping tools like ParseHub, OctoParse, and WebHarvy

# %% [markdown]
# In this documentation, I will scrape data from variety of sources which includes: Twitter, Instagram, Facebook, Google App, Apple Store, Website, News Headlines, Youtube comments, Websites in general

# %% [markdown]
# ## Google Play

# %% [markdown]
# ### Import Library

# %%
#install package
# !pip install google-play-scraper
#Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.10/dist-packages (1.2.4)

#import app, sort, reviews_all is to scrape ALL the reviews
from google_play_scraper import app,Sort, reviews_all, reviews
import pandas as pd
import numpy as np #linear algebra library

# %%
#Scrapping Reviews GOJEK from Google Play
#to only scrape certain amount of data, use "your_new_variable, continuation_token=reviews"
#to scrape all, use reviews_all
gojek_all_reviews = reviews_all(mi
                              'com.gojek.app', #add your app site here
                              sleep_milliseconds=0, # defaults to 0
                              lang='id', # defaults to 'en'
                              country='ID', # defaults to 'us'
                              sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT,
                              filter_score_with= None,#based on your desired feature
                          )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-a975fe572098> in <cell line: 4>()
#       2 #to only scrape certain amount of data, use "your_new_variable, continuation_token=reviews"
#       3 #to scrape all, use reviews_all
# ----> 4 gojek_all_reviews = reviews_all(
#       5                               'com.gojek.app', #add your app site here
#       6                               sleep_milliseconds=0, # defaults to 0
#
# /usr/local/lib/python3.10/dist-packages/google_play_scraper/features/reviews.py in reviews_all(app_id, sleep_milliseconds, **kwargs)
#     125
#     126     while True:
# --> 127         _result, continuation_token = reviews(
#     128             app_id,
#     129             count=MAX_COUNT_EACH_FETCH,
#
# ...

# %%
#list to dataframe
df_all_gojek = pd.DataFrame(np.array(gojek_all_reviews),columns=['review'])
df_all_gojek = df_all_gojek.join(pd.DataFrame(df_all_gojek.pop('review').tolist()))
print(df_all_gojek)
df_all_gojek.head()

# %%
gojek_reviews, continuation_token=reviews(
                                  'com.gojek.app', #The target web
                                  lang='id', # defaults to 'en'
                                  country='ID', # defaults to 'us'
                                  sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
                                  count=2000,#scrap only 20k newest data
                                  filter_score_with=None #default to none(means all score 1,2,3,4,5)
)

# %%
#list to dataframe
df_gojek = pd.DataFrame(np.array(gojek_reviews),columns=['review'])
df_gojek = df_gojek.join(pd.DataFrame(df_gojek.pop('review').tolist()))
print(df_gojek.shape)
df_gojek.head()
# Out:
# (2000, 11)
#                                reviewId                       userName  \
# 0  463eb366-99f8-4de8-88ee-6168a03615d1                   Sigit Widodo
# 1  50c90273-58ac-4f7e-ba09-90524db45363  21-028 _Nashya Alifah Admiral
# 2  5477ffaa-0dc1-4ce4-bdf2-eca5bb7077d5                 Riski Syakhieb
# 3  fd6b631e-d1d7-408c-b78a-e8cfbe5346ba                ema nur hidayah
# 4  dcc24529-1507-45bf-a4a1-b0b06f25a963                      Agus Wedi
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0                                     Makasih go jek      5              0
# ...

# %% [markdown]
# ## Twitter

# %% [markdown]
# Considering Elon Musk has limited the users to scroll through the tweets per day, so the data will be limited to less than 1000

# %%
# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Get:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease [18.1 kB]
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,005 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [1,254 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,082 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,270 kB]
# ...

# %%
# Crawl Data

filename = 'anies.csv'
search_keyword = 'anies baswedan until:2023-09-30 since:2023-08-01'
limit = 10000

# !npx --yes tweet-harvest@latest -o "{filename}" -s "{search_keyword}" -l {limit} --token ""
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=";")

# Display the DataFrame
print(df.shape)
display(df)

# %% [markdown]
# ## Scrape News Headlines

# %% [markdown]
# https://esairina.medium.com/scraping-berita-online-pada-situs-detik-com-menggunakan-google-colab-3a764981384b

# %%
import requests as req
from bs4 import BeautifulSoup as bs
from datetime import datetime
import csv
hades = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36'}

# %%
def scrape_detik(hal):
    global hades
    a = 1
    for page in range(1,hal):
        url = f'https://www.detik.com/search/searchnews?query=pemilu+2024&sortby=time&page={page}'
        ge = req.get(url,hades,allow_redirects=False).text
        sop = bs(ge,'lxml')
        li = sop.find('div',class_='list media_rows list-berita')
        lin = li.find_all('article')
        for x in lin:
            link = x.find('a')['href']
            date = x.find('a').find('span',class_='date').text.replace('WIB','').replace('detikNews','').split(',')[1]
            headline = x.find('a').find('h2').text
            ge_ = req.get(link,hades, allow_redirects=False).text
            sop_ = bs(ge_,'lxml')
            content = sop_.find_all('div',class_='detail__body-text itp_bodycontent')
            for x in content:
                x = x.find_all('p')
                y  = [y.text for y in x ]
                content_ = ''.join(y).replace('\n', '').replace('ADVERTISEMENT','').replace('SCROLL TO RESUME CONTENT','')
                print(f'done[{a}] > {headline[0:10]}')
                a += 1
                with open('politik.csv','a')as file:
                    wr = csv.writer(file, delimiter=',')
                    wr.writerow([headline,date,link,content_])

# %%
scrape_detik(11)
# Out:
# done[1] > Respons Ka
# done[2] > Kagetnya K
# done[3] > Jalan Seki
# done[4] > Sandiaga S
# done[5] > Golkar Und
# done[6] > Pentas Sen
# done[7] > Golkar Tun
# done[8] > Anies-Cak
# done[9] > Anwar Usma
# done[10] > Apresiasi
# done[11] > Hasil Surv
# done[12] > Basarah: 4
# done[13] > Mahfud Md
# done[14] > Menanti Ca
# done[15] > Ma'ruf Nil
# done[16] > Cerita Kep
# done[17] > 2.000 Pers
# done[18] > Survei UMM
# done[19] > Pakar Pred
# done[20] > Jokowi Sud
# done[21] > Bamsoet Aj
# done[22] > Partai Gol
# done[23] > Diminta Bu
# done[24] > Jawaban Sa
# done[25] > Ganjar-Mah
# done[26] > Anies Gela
# done[27] > Sambut Due
# done[28] > Gatot Akan
# done[29] > PAN Ungkap
# done[30] > LMND: Pro
# done[31] > Gatot Krit
# done[32] > Mahfud Jad
# done[33] > Artis Ibu
# done[34] > Pendaftara
# done[35] > Yakin Ganj
# done[36] > Beredar Ka
# done[37] > Jurkam AMI
# done[38] > Amien Rais
# done[39] > PKB Tak Kh
# done[40] > Tahapan da
# done[41] > PAN Jatim
# done[42] > Golkar Bak
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/politik.csv')

print(df.shape)
df.head()
# Out:
# (217, 4)
#   Jalan Sekitar KPU Ditutup Saat Pendaftaran Capres Besok, Ini Alternatifnya  \
# 0  Sandiaga Sebut Ganjar Mahfud Pilihan RI: Walau...
# 1  Golkar Undang Seluruh Parpol KIM di Puncak Per...
# 2  Pentas Seni HUT ke-354 Sulsel, Bahtiar: Sudah ...
# 3  Golkar Tunjuk Nusron Wahid Masuk Tim Kampanye ...
# 4  Anies-Cak Imin Bersama Elite Koalisi Doa Bersa...
#
#     18 Okt 2023 22:58   \
# 0   18 Okt 2023 22:45
# 1   18 Okt 2023 22:45
# 2   18 Okt 2023 22:38
# 3   18 Okt 2023 22:37
# 4   18 Okt 2023 22:34
#
#   https://news.detik.com/pemilu/d-6989962/jalan-sekitar-kpu-ditutup-saat-pendaftaran-capres-besok-ini-alternatifnya  \
# 0  https://news.detik.com/pemilu/d-6989954/sandia...
# 1  https://news.detik.com/pemilu/d-6989953/golkar...
# 2  https://www.detik.com/sulsel/berita/d-6989949/...
# 3  https://news.detik.com/pemilu/d-6989948/golkar...
# 4  https://news.detik.com/pemilu/d-6989947/anies-...
#
# ...

# %% [markdown]
# ## Scraping Image

# %% [markdown]
# https://www.youtube.com/watch?v=NcsiXa_74jM&ab_channel=TonyTeachesTech
